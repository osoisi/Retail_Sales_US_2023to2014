# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\aa1\AppData\Local\Temp\ipykernel_54724\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\aa1\Desktop\python_projects\retail_sales_us_gov\Retail_Sales_US_2023to2014\Source Files\retail_sales_2023to2014.csv')

# %%
df
# Out:
#      Year       Code                                           Industry  \
# 0    2023        441                    Motor vehicle and parts dealers
# 1    2023  4411,4412         Automobile and other motor vehicle dealers
# 2    2023       4413            Automotive parts, acc., and tire stores
# 3    2023    442,443  Furniture, home furn, electronics, and applian...
# 4    2023        442              Furniture and home furnishings stores
# ..    ...        ...                                                ...
# 305  2014        453                     Miscellaneous stores retailers
# 306  2014        454                                 Nonstore retailers
# 307  2014       4541          Electronic shopping and mail order houses
# 308  2014      45431                                       Fuel dealers
# 309  2014        722                  Food services and drinking places
#
#     Jan. 2022 Feb. 2022 Mar. 2022 Apr. 2022 May 2022 Jun. 2022 Jul. 2022  \
# ...

# %% [markdown]
# ## Issues with the data frame
# Some of the dataframe column headers are wrong. Jan. 2022 should be January as the dates have their own column. I have researched other sources to see that this was an entry error when this CSV version was compiled from the multi-year version.

# %%
df.describe()
# Out:
#               Year  TOTAL  Unnamed: 16
# count   310.000000    0.0          0.0
# mean   2018.500000    NaN          NaN
# std       2.876925    NaN          NaN
# min    2014.000000    NaN          NaN
# 25%    2016.000000    NaN          NaN
# 50%    2018.500000    NaN          NaN
# 75%    2021.000000    NaN          NaN
# max    2023.000000    NaN          NaN

# %% [markdown]
# Mixed data types in columns did not allow for df.describe to yield any meaningful results.

# %%
df
# Out:
#      Year       Code                                           Industry  \
# 0    2023        441                    Motor vehicle and parts dealers
# 1    2023  4411,4412         Automobile and other motor vehicle dealers
# 2    2023       4413            Automotive parts, acc., and tire stores
# 3    2023    442,443  Furniture, home furn, electronics, and applian...
# 4    2023        442              Furniture and home furnishings stores
# ..    ...        ...                                                ...
# 305  2014        453                     Miscellaneous stores retailers
# 306  2014        454                                 Nonstore retailers
# 307  2014       4541          Electronic shopping and mail order houses
# 308  2014      45431                                       Fuel dealers
# 309  2014        722                  Food services and drinking places
#
#     Jan. 2022 Feb. 2022 Mar. 2022 Apr. 2022 May 2022 Jun. 2022 Jul. 2022  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         310 non-null    int64
#  1   Code         310 non-null    object
#  2   Industry     310 non-null    object
#  3   Jan. 2022    310 non-null    object
#  4   Feb. 2022    310 non-null    object
#  5   Mar. 2022    310 non-null    object
#  6   Apr. 2022    310 non-null    object
#  7   May 2022     310 non-null    object
#  8   Jun. 2022    310 non-null    object
#  9   Jul. 2022    310 non-null    object
#  10  Aug. 2022    310 non-null    object
#  11  Sep. 2022    310 non-null    object
#  12  Oct. 2022    310 non-null    object
#  13  Nov. 2022    310 non-null    object
#  14  Dec. 2022    279 non-null    object
#  15  TOTAL        0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
# dtypes: float64(2), int64(1), object(14)
# memory usage: 41.3+ KB

# %% [markdown]
# Dec. 2022 data has missing fields.

# %%
df.nunique()
# Out:
# Year            10
# Code            31
# Industry        31
# Jan. 2022      305
# Feb. 2022      305
# Mar. 2022      306
# Apr. 2022      305
# May 2022       301
# Jun. 2022      304
# Jul. 2022      304
# Aug. 2022      304
# Sep. 2022      304
# Oct. 2022      301
# Nov. 2022      303
# Dec. 2022      276
# TOTAL            0
# Unnamed: 16      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Year             0
# Code             0
# Industry         0
# Jan. 2022        0
# Feb. 2022        0
# Mar. 2022        0
# Apr. 2022        0
# May 2022         0
# Jun. 2022        0
# Jul. 2022        0
# Aug. 2022        0
# Sep. 2022        0
# Oct. 2022        0
# Nov. 2022        0
# Dec. 2022       31
# TOTAL          310
# Unnamed: 16    310
# dtype: int64

# %%
df2=df

# %%
df2['Jan. 2022']=df['Jan. 2022'].replace('(S)', np.nan)

# %%
df2
# Out:
#      Year       Code                                           Industry  \
# 0    2023        441                    Motor vehicle and parts dealers
# 1    2023  4411,4412         Automobile and other motor vehicle dealers
# 2    2023       4413            Automotive parts, acc., and tire stores
# 3    2023    442,443  Furniture, home furn, electronics, and applian...
# 4    2023        442              Furniture and home furnishings stores
# ..    ...        ...                                                ...
# 305  2014        453                     Miscellaneous stores retailers
# 306  2014        454                                 Nonstore retailers
# 307  2014       4541          Electronic shopping and mail order houses
# 308  2014      45431                                       Fuel dealers
# 309  2014        722                  Food services and drinking places
#
#     Jan. 2022 Feb. 2022 Mar. 2022 Apr. 2022 May 2022 Jun. 2022 Jul. 2022  \
# ...

# %%
columns2replace = ['Jan. 2022', 'Feb. 2022', 'Mar. 2022', 'Apr. 2022', 'May 2022']
for column in columns2replace:
    df[column]=df[column].replace('(S)', np.nan)

# %% [markdown]
# Opened the CSV file here on VS code and found entries with value (S) which need to be replaced.
# Wrote this simple for loop for replacing entries of (S) with NULL.

# %%
df2.to_csv('C:\\Users\\aa1\\Desktop\\python_projects\\retail_sales_us_gov\\Retail_Sales_US_2023to2014\\Source Files\\retail_sales_2023to2014_new.csv')

# %%
df2
# Out:
#      Year       Code                                           Industry  \
# 0    2023        441                    Motor vehicle and parts dealers
# 1    2023  4411,4412         Automobile and other motor vehicle dealers
# 2    2023       4413            Automotive parts, acc., and tire stores
# 3    2023    442,443  Furniture, home furn, electronics, and applian...
# 4    2023        442              Furniture and home furnishings stores
# ..    ...        ...                                                ...
# 305  2014        453                     Miscellaneous stores retailers
# 306  2014        454                                 Nonstore retailers
# 307  2014       4541          Electronic shopping and mail order houses
# 308  2014      45431                                       Fuel dealers
# 309  2014        722                  Food services and drinking places
#
#     Jan. 2022 Feb. 2022 Mar. 2022 Apr. 2022 May 2022 Jun. 2022 Jul. 2022  \
# ...

# %%
df2=df2.drop(columns='Unnamed: 16')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df2=df2.drop(columns='Unnamed: 16')
#
# File c:\Users\aa1\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
# ...

# %%
df2
# Out:
#      Year       Code                                           Industry  \
# 0    2023        441                    Motor vehicle and parts dealers
# 1    2023  4411,4412         Automobile and other motor vehicle dealers
# 2    2023       4413            Automotive parts, acc., and tire stores
# 3    2023    442,443  Furniture, home furn, electronics, and applian...
# 4    2023        442              Furniture and home furnishings stores
# ..    ...        ...                                                ...
# 305  2014        453                     Miscellaneous stores retailers
# 306  2014        454                                 Nonstore retailers
# 307  2014       4541          Electronic shopping and mail order houses
# 308  2014      45431                                       Fuel dealers
# 309  2014        722                  Food services and drinking places
#
#     Jan. 2022 Feb. 2022 Mar. 2022 Apr. 2022 May 2022 Jun. 2022 Jul. 2022  \
# ...

# %%
columns2replace2=['Jun. 2022',	'Jul. 2022',	'Aug. 2022',	'Sep. 2022',	'Oct. 2022',	'Nov. 2022',	'Dec. 2022',	'TOTAL']
for column in columns2replace2:
    df2[column]=df2[column].replace('(S)', np.nan)

# %%
df2
# Out:
#      Year       Code                                           Industry  \
# 0    2023        441                    Motor vehicle and parts dealers
# 1    2023  4411,4412         Automobile and other motor vehicle dealers
# 2    2023       4413            Automotive parts, acc., and tire stores
# 3    2023    442,443  Furniture, home furn, electronics, and applian...
# 4    2023        442              Furniture and home furnishings stores
# ..    ...        ...                                                ...
# 305  2014        453                     Miscellaneous stores retailers
# 306  2014        454                                 Nonstore retailers
# 307  2014       4541          Electronic shopping and mail order houses
# 308  2014      45431                                       Fuel dealers
# 309  2014        722                  Food services and drinking places
#
#     Jan. 2022 Feb. 2022 Mar. 2022 Apr. 2022 May 2022 Jun. 2022 Jul. 2022  \
# ...

# %%
columns2check1 = ['Nov. 2022', 'Dec. 2022', 'TOTAL']
columnswithS = df2[columns2check1].isin(['(S)']).any(axis=1).any()

print(columnswithS)
# Out:
# False

# %%
df2
# Out:
#      Year       Code                                           Industry  \
# 0    2023        441                    Motor vehicle and parts dealers
# 1    2023  4411,4412         Automobile and other motor vehicle dealers
# 2    2023       4413            Automotive parts, acc., and tire stores
# 3    2023    442,443  Furniture, home furn, electronics, and applian...
# 4    2023        442              Furniture and home furnishings stores
# ..    ...        ...                                                ...
# 305  2014        453                     Miscellaneous stores retailers
# 306  2014        454                                 Nonstore retailers
# 307  2014       4541          Electronic shopping and mail order houses
# 308  2014      45431                                       Fuel dealers
# 309  2014        722                  Food services and drinking places
#
#     Jan. 2022 Feb. 2022 Mar. 2022 Apr. 2022 May 2022 Jun. 2022 Jul. 2022  \
# ...

# %%
columns2check2=['Jan. 2022', 'Feb. 2022', 'Mar. 2022', 'Apr. 2022', 'May 2022']
columnswithS2=df2[columns2check2].isin(['(S)']).any(axis=1).any()
print(columnswithS2)
# Out:
# False

# %%
df2
# Out:
#      Year       Code                                           Industry  \
# 0    2023        441                    Motor vehicle and parts dealers
# 1    2023  4411,4412         Automobile and other motor vehicle dealers
# 2    2023       4413            Automotive parts, acc., and tire stores
# 3    2023    442,443  Furniture, home furn, electronics, and applian...
# 4    2023        442              Furniture and home furnishings stores
# ..    ...        ...                                                ...
# 305  2014        453                     Miscellaneous stores retailers
# 306  2014        454                                 Nonstore retailers
# 307  2014       4541          Electronic shopping and mail order houses
# 308  2014      45431                                       Fuel dealers
# 309  2014        722                  Food services and drinking places
#
#     Jan. 2022 Feb. 2022 Mar. 2022 Apr. 2022 May 2022 Jun. 2022 Jul. 2022  \
# ...

# %%
df2.to_csv('C:\\Users\\aa1\\Desktop\\python_projects\\retail_sales_us_gov\\Retail_Sales_US_2023to2014\\Source Files\\retail_sales_2023to2014new.csv')

# %% [markdown]
# Create a new CSV file with the slightly improved data. This will be imported into a new Database to completed the cleaning process with MSSQL and Azure Data Studio.

# %%
trans_df = df2.transpose()

# %%
trans_df
# Out:
#                                        0    \
# Year                                  2023
# Code                                   441
# Industry   Motor vehicle and parts dealers
# Jan. 2022                          132,820
# Feb. 2022                          131,337
# Mar. 2022                          129,662
# Apr. 2022                          130,767
# May 2022                           132,976
# Jun. 2022                          133,682
# Jul. 2022                          133,333
# Aug. 2022                          133,786
# Sep. 2022                          135,260
# Oct. 2022                          133,940
# Nov. 2022                          135,006
# Dec. 2022                              NaN
# TOTAL                                  NaN
#
#                                                   1    \
# Year                                             2023
# Code                                        4411,4412
# Industry   Automobile and other motor vehicle dealers
# ...

# %%
trans_df=trans_df.drop(trans_df.index[15])

# %%
trans_df
# Out:
#                                        0    \
# Year                                  2023
# Code                                   441
# Industry   Motor vehicle and parts dealers
# Jan. 2022                          132,820
# Feb. 2022                          131,337
# Mar. 2022                          129,662
# Apr. 2022                          130,767
# May 2022                           132,976
# Jun. 2022                          133,682
# Jul. 2022                          133,333
# Aug. 2022                          133,786
# Sep. 2022                          135,260
# Oct. 2022                          133,940
# Nov. 2022                          135,006
# Dec. 2022                              NaN
#
#                                                   1    \
# Year                                             2023
# Code                                        4411,4412
# Industry   Automobile and other motor vehicle dealers
# ...

# %%
trans_df.to_csv('C:\\Users\\aa1\\Desktop\\python_projects\\retail_sales_us_gov\\Retail_Sales_US_2023to2014\\Source Files\\retail_sales_2023to2014trans.csv')

# %%
fixed_trans_df=trans_df.reset_index()

# %%
fixed_trans_df
# Out:
#         index                                0  \
# 0        Year                             2023
# 1        Code                              441
# 2    Industry  Motor vehicle and parts dealers
# 3   Jan. 2022                          132,820
# 4   Feb. 2022                          131,337
# 5   Mar. 2022                          129,662
# 6   Apr. 2022                          130,767
# 7    May 2022                          132,976
# 8   Jun. 2022                          133,682
# 9   Jul. 2022                          133,333
# 10  Aug. 2022                          133,786
# 11  Sep. 2022                          135,260
# 12  Oct. 2022                          133,940
# 13  Nov. 2022                          135,006
# 14  Dec. 2022                              NaN
#
#                                              1  \
# 0                                         2023
# 1                                    4411,4412
# 2   Automobile and other motor vehicle dealers
# ...

# %%
fixed_trans_df.to_csv('C:\\Users\\aa1\\Desktop\\python_projects\\retail_sales_us_gov\\Retail_Sales_US_2023to2014\\Source Files\\retail_sales_2023to2014trans.csv')

# %%
fixed_trans_df.iloc[0]
# Out:
# index    Year
# 0        2023
# 1        2023
# 2        2023
# 3        2023
#          ...
# 305      2014
# 306      2014
# 307      2014
# 308      2014
# 309      2014
# Name: 0, Length: 311, dtype: object

# %%
fixed_trans_df.to_excel('C:\\Users\\aa1\\Desktop\\python_projects\\retail_sales_us_gov\\Retail_Sales_US_2023to2014\\Source Files\\retail_sales_2023to2014trans.xlsx')
